# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings(action='ignore')

# %%
df = pd.read_csv("cirrhosis.csv")
df
# Out:
#       ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  21464   F       Y            Y
# 1      2    4500      C  D-penicillamine  20617   F       N            Y
# 2      3    1012      D  D-penicillamine  25594   M       N            N
# 3      4    1925      D  D-penicillamine  19994   F       N            Y
# 4      5    1504     CL          Placebo  13918   F       N            Y
# ..   ...     ...    ...              ...    ...  ..     ...          ...
# 413  414     681      D              NaN  24472   F     NaN          NaN
# 414  415    1103      C              NaN  14245   F     NaN          NaN
# 415  416    1055      C              NaN  20819   F     NaN          NaN
# 416  417     691      C              NaN  21185   F     NaN          NaN
# 417  418     976      C              NaN  19358   F     NaN          NaN
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# ...

# %%
df.shape
# Out:
# (418, 20)

# %%
df.head(5)
# Out:
#    ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly Spiders  \
# 0   1     400      D  D-penicillamine  21464   F       Y            Y       Y
# 1   2    4500      C  D-penicillamine  20617   F       N            Y       Y
# 2   3    1012      D  D-penicillamine  25594   M       N            N       N
# 3   4    1925      D  D-penicillamine  19994   F       N            Y       Y
# 4   5    1504     CL          Placebo  13918   F       N            Y       Y
#
#   Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0     Y       14.5        261.0     2.60   156.0    1718.0  137.95
# 1     N        1.1        302.0     4.14    54.0    7394.8  113.52
# 2     S        1.4        176.0     3.48   210.0     516.0   96.10
# 3     S        1.8        244.0     2.54    64.0    6121.8   60.63
# 4     N        3.4        279.0     3.53   143.0     671.0  113.15
#
#    Tryglicerides  Platelets  Prothrombin  Stage
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             418 non-null    int64
#  1   N_Days         418 non-null    int64
#  2   Status         418 non-null    object
#  3   Drug           312 non-null    object
#  4   Age            418 non-null    int64
#  5   Sex            418 non-null    object
#  6   Ascites        312 non-null    object
#  7   Hepatomegaly   312 non-null    object
#  8   Spiders        312 non-null    object
#  9   Edema          418 non-null    object
#  10  Bilirubin      418 non-null    float64
#  11  Cholesterol    284 non-null    float64
#  12  Albumin        418 non-null    float64
#  13  Copper         310 non-null    float64
#  14  Alk_Phos       312 non-null    float64
#  15  SGOT           312 non-null    float64
#  16  Tryglicerides  282 non-null    float64
# ...

# %%
df.describe()
# Out:
#                ID       N_Days           Age   Bilirubin  Cholesterol  \
# count  418.000000   418.000000    418.000000  418.000000   284.000000
# mean   209.500000  1917.782297  18533.351675    3.220813   369.510563
# std    120.810458  1104.672992   3815.845055    4.407506   231.944545
# min      1.000000    41.000000   9598.000000    0.300000   120.000000
# 25%    105.250000  1092.750000  15644.500000    0.800000   249.500000
# 50%    209.500000  1730.000000  18628.000000    1.400000   309.500000
# 75%    313.750000  2613.500000  21272.500000    3.400000   400.000000
# max    418.000000  4795.000000  28650.000000   28.000000  1775.000000
#
#           Albumin      Copper      Alk_Phos        SGOT  Tryglicerides  \
# count  418.000000  310.000000    312.000000  312.000000     282.000000
# mean     3.497440   97.648387   1982.655769  122.556346     124.702128
# std      0.424972   85.613920   2140.388824   56.699525      65.148639
# ...

# %%
df.columns
# Out:
# Index(['ID', 'N_Days', 'Status', 'Drug', 'Age', 'Sex', 'Ascites',
#        'Hepatomegaly', 'Spiders', 'Edema', 'Bilirubin', 'Cholesterol',
#        'Albumin', 'Copper', 'Alk_Phos', 'SGOT', 'Tryglicerides', 'Platelets',
#        'Prothrombin', 'Stage'],
#       dtype='object')

# %%
df_o=df.select_dtypes('object')
df_o
# Out:
#     Status             Drug Sex Ascites Hepatomegaly Spiders Edema
# 0        D  D-penicillamine   F       Y            Y       Y     Y
# 1        C  D-penicillamine   F       N            Y       Y     N
# 2        D  D-penicillamine   M       N            N       N     S
# 3        D  D-penicillamine   F       N            Y       Y     S
# 4       CL          Placebo   F       N            Y       Y     N
# ..     ...              ...  ..     ...          ...     ...   ...
# 413      D              NaN   F     NaN          NaN     NaN     N
# 414      C              NaN   F     NaN          NaN     NaN     N
# 415      C              NaN   F     NaN          NaN     NaN     N
# 416      C              NaN   F     NaN          NaN     NaN     N
# 417      C              NaN   F     NaN          NaN     NaN     N
#
# [418 rows x 7 columns]

# %%
df_f = df.select_dtypes('float64')
df_f
# Out:
#      Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  Tryglicerides  \
# 0         14.5        261.0     2.60   156.0    1718.0  137.95          172.0
# 1          1.1        302.0     4.14    54.0    7394.8  113.52           88.0
# 2          1.4        176.0     3.48   210.0     516.0   96.10           55.0
# 3          1.8        244.0     2.54    64.0    6121.8   60.63           92.0
# 4          3.4        279.0     3.53   143.0     671.0  113.15           72.0
# ..         ...          ...      ...     ...       ...     ...            ...
# 413        1.2          NaN     2.96     NaN       NaN     NaN            NaN
# 414        0.9          NaN     3.83     NaN       NaN     NaN            NaN
# 415        1.6          NaN     3.42     NaN       NaN     NaN            NaN
# 416        0.8          NaN     3.75     NaN       NaN     NaN            NaN
# 417        0.7          NaN     3.29     NaN       NaN     NaN            NaN
#
# ...

# %%
df_i = df.select_dtypes( 'int64')
df_i
# Out:
#       ID  N_Days    Age
# 0      1     400  21464
# 1      2    4500  20617
# 2      3    1012  25594
# 3      4    1925  19994
# 4      5    1504  13918
# ..   ...     ...    ...
# 413  414     681  24472
# 414  415    1103  14245
# 415  416    1055  20819
# 416  417     691  21185
# 417  418     976  19358
#
# [418 rows x 3 columns]

# %%
data = df.drop(columns=['Drug','Status','Sex',	'Ascites','Hepatomegaly','Spiders','Edema'])
data
# Out:
#       ID  N_Days    Age  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos  \
# 0      1     400  21464       14.5        261.0     2.60   156.0    1718.0
# 1      2    4500  20617        1.1        302.0     4.14    54.0    7394.8
# 2      3    1012  25594        1.4        176.0     3.48   210.0     516.0
# 3      4    1925  19994        1.8        244.0     2.54    64.0    6121.8
# 4      5    1504  13918        3.4        279.0     3.53   143.0     671.0
# ..   ...     ...    ...        ...          ...      ...     ...       ...
# 413  414     681  24472        1.2          NaN     2.96     NaN       NaN
# 414  415    1103  14245        0.9          NaN     3.83     NaN       NaN
# 415  416    1055  20819        1.6          NaN     3.42     NaN       NaN
# 416  417     691  21185        0.8          NaN     3.75     NaN       NaN
# 417  418     976  19358        0.7          NaN     3.29     NaN       NaN
#
#        SGOT  Tryglicerides  Platelets  Prothrombin  Stage
# ...

# %%
data['Age'] = (data['Age']/365).astype("int")

# %%
df.isnull().sum()
# Out:
# ID                 0
# N_Days             0
# Status             0
# Drug             106
# Age                0
# Sex                0
# Ascites          106
# Hepatomegaly     106
# Spiders          106
# Edema              0
# Bilirubin          0
# Cholesterol      134
# Albumin            0
# Copper           108
# Alk_Phos         106
# SGOT             106
# Tryglicerides    136
# Platelets         11
# Prothrombin        2
# Stage              6
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
s_imputer = SimpleImputer(missing_values=np.nan,strategy='mean',verbose=0)
s_imputer = s_imputer.fit(data[3:])
data[3:] = s_imputer.transform(data[3:])

# %%
data
# Out:
#         ID  N_Days   Age  Bilirubin  Cholesterol  Albumin      Copper  \
# 0      1.0   400.0  58.0       14.5   261.000000     2.60  156.000000
# 1      2.0  4500.0  56.0        1.1   302.000000     4.14   54.000000
# 2      3.0  1012.0  70.0        1.4   176.000000     3.48  210.000000
# 3      4.0  1925.0  54.0        1.8   244.000000     2.54   64.000000
# 4      5.0  1504.0  38.0        3.4   279.000000     3.53  143.000000
# ..     ...     ...   ...        ...          ...      ...         ...
# 413  414.0   681.0  67.0        1.2   370.825623     2.96   97.234528
# 414  415.0  1103.0  39.0        0.9   370.825623     3.83   97.234528
# 415  416.0  1055.0  57.0        1.6   370.825623     3.42   97.234528
# 416  417.0   691.0  58.0        0.8   370.825623     3.75   97.234528
# 417  418.0   976.0  53.0        0.7   370.825623     3.29   97.234528
#
#         Alk_Phos        SGOT  Tryglicerides  Platelets  Prothrombin  Stage
# ...

# %%
plt.figure(figsize=(20,20),facecolor ="r")
plotnumber=1

for column in data:
  if plotnumber<=15:
    ax = plt.subplot(5,3,plotnumber)
    sns.distplot(data[column])
    plt.xlabel(column,fontsize = 20)

  plotnumber+=1
plt.tight_layout()   
plt.show()

# %%
plt.figure(figsize=(20,20),facecolor ="r")
plotnumber=1

for column in data:
  if plotnumber<=15:
    ax = plt.subplot(5,3,plotnumber)
    sns.distplot(data[column])
    plt.xlabel(column,fontsize = 20)

  plotnumber+=1
plt.tight_layout()   
plt.show()

# %%
plt.figure(figsize=(20,20),facecolor ="r")
plotnumber=1

for column in data:
  if plotnumber<=15:
    ax = plt.subplot(5,3,plotnumber)
    sns.boxplot(data[column])
    plt.xlabel(column,fontsize = 20)

  plotnumber+=1
plt.tight_layout()   
plt.show()

# %%
plt.figure(figsize=(20,20),facecolor ="r")
plotnumber=1

for column in data:
  if plotnumber<=15:
    ax = plt.subplot(5,3,plotnumber)
    sns.kdeplot(data[column])
    plt.xlabel(column,fontsize = 20)

  plotnumber+=1
plt.tight_layout()   
plt.show()

# %% [markdown]
# categorical data

# %%
sns.countplot(df['Drug'])
plt.show()

# %%
sns.countplot(df['Status'])
plt.show()

# %%
sns.countplot(df['Sex'])
plt.show()

# %%
sns.countplot(df['Ascites'])
plt.show()

# %%
sns.countplot(df['Hepatomegaly'])
plt.show()

# %%
sns.countplot(df['Spiders'])
plt.show()

# %%
sns.countplot(df['Edema'])
plt.show()

# %%
correlation = data.corr()
correlation
# Out:
#                      ID    N_Days       Age  Bilirubin  Cholesterol   Albumin  \
# ID             1.000000 -0.354305  0.053245  -0.062154     0.022492 -0.128924
# N_Days        -0.354305  1.000000 -0.127958  -0.403953    -0.114995  0.430829
# Age            0.053245 -0.127958  1.000000   0.000871    -0.129301 -0.181863
# Bilirubin     -0.062154 -0.403953  0.000871   1.000000     0.337748 -0.314177
# Cholesterol    0.022492 -0.114995 -0.129301   0.337748     1.000000 -0.054814
# Albumin       -0.128924  0.430829 -0.181863  -0.314177    -0.054814  1.000000
# Copper        -0.065366 -0.319423  0.052064   0.405275     0.122871 -0.225291
# Alk_Phos      -0.229658  0.131466 -0.042785   0.103880     0.140089 -0.086314
# SGOT          -0.007365 -0.198094 -0.131358   0.392099     0.337155 -0.187814
# Tryglicerides -0.020053 -0.127093  0.016925   0.371454     0.276833 -0.080951
# Platelets     -0.075533  0.147610 -0.146733  -0.013378     0.150450  0.156466
# ...

# %%
sns.set({'figure.figsize':(8,6)})
sns.heatmap(data=correlation)
plt.title('HEATMAP')
plt.show()

# %%
X = data.drop(columns=['Stage','ID'])
print(X)
# Out:
#      N_Days   Age  Bilirubin  Cholesterol  Albumin      Copper     Alk_Phos  \
# 0     400.0  58.0       14.5   261.000000     2.60  156.000000  1718.000000
# 1    4500.0  56.0        1.1   302.000000     4.14   54.000000  7394.800000
# 2    1012.0  70.0        1.4   176.000000     3.48  210.000000   516.000000
# 3    1925.0  54.0        1.8   244.000000     2.54   64.000000  6121.800000
# 4    1504.0  38.0        3.4   279.000000     3.53  143.000000   671.000000
# ..      ...   ...        ...          ...      ...         ...          ...
# 413   681.0  67.0        1.2   370.825623     2.96   97.234528  1970.743689
# 414  1103.0  39.0        0.9   370.825623     3.83   97.234528  1970.743689
# 415  1055.0  57.0        1.6   370.825623     3.42   97.234528  1970.743689
# 416   691.0  58.0        0.8   370.825623     3.75   97.234528  1970.743689
# 417   976.0  53.0        0.7   370.825623     3.29   97.234528  1970.743689
#
#            SGOT  Tryglicerides  Platelets  Prothrombin
# ...

# %%
data['Stage'] = np.floor(data['Stage']).astype("int")

# %%
data['Stage'].value_counts()
# Out:
# 3    161
# 4    144
# 2     92
# 1     21
# Name: Stage, dtype: int64

# %%
y = data['Stage']

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE()

X_sample, y_sample = smote.fit_resample(X, y)

print('Original dataset \n',y.value_counts()) 
print('Resample dataset \n', y_sample.value_counts())
# Out:
# Original dataset
#  3    161
# 4    144
# 2     92
# 1     21
# Name: Stage, dtype: int64
# Resample dataset
#  1    161
# 2    161
# 3    161
# 4    161
# Name: Stage, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_sample,y_sample,test_size=0.2,random_state=2)

# %%
X_train
# Out:
#           N_Days        Age  Bilirubin  Cholesterol   Albumin     Copper  \
# 370   489.000000  51.000000   7.300000   370.825623  3.520000  97.234528
# 571  3250.153820  47.524495   0.734966   283.100349  4.053566  15.021012
# 455  2773.663828  38.615400   0.934265   370.825623  3.386782  70.223993
# 123  3069.000000  52.000000   0.600000   251.000000  3.900000  25.000000
# 471  3099.430010  54.854457   0.545034   214.748286  3.931062  41.880113
# ..           ...        ...        ...          ...       ...        ...
# 534  3456.340002  59.510795   0.667887   216.978411  3.981347  17.241325
# 584  3506.516705  53.719794   3.672494   370.825623  4.175604  97.234528
# 493  1354.882628  39.594810   1.184311   328.469556  3.800260  85.646829
# 527  1416.425225  45.004824   0.762681   249.641282  3.411582  59.650930
# 168  1212.000000  35.000000   1.300000   408.000000  4.220000  67.000000
#
#         Alk_Phos        SGOT  Tryglicerides   Platelets  Prothrombin
# ...

# %%
y_train
# Out:
# 370    1
# 571    2
# 455    1
# 123    4
# 471    1
#       ..
# 534    1
# 584    2
# 493    1
# 527    1
# 168    3
# Name: Stage, Length: 515, dtype: int32

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble  import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
models = []
models.append(("LogisticRegression",LogisticRegression()))
models.append(("DescisionTree",DecisionTreeClassifier()))
models.append(("RandomForest",RandomForestClassifier()))
models.append(("SupportVector",SVC()))
models.append(("KNeighbors",KNeighborsClassifier()))

# %%
for name,model in models:
    model.fit(X_train,y_train)
    train_score = model.score(X_train,y_train)
    test_score = model.score(X_test,y_test)
    print(name,"train score =",train_score)
    print(name,"test score =",test_score)
# Out:
# LogisticRegression train score = 0.47378640776699027
# LogisticRegression test score = 0.4263565891472868
# DescisionTree train score = 1.0
# DescisionTree test score = 0.5426356589147286
# RandomForest train score = 1.0
# RandomForest test score = 0.627906976744186
# SupportVector train score = 0.42524271844660194
# SupportVector test score = 0.3875968992248062
# KNeighbors train score = 0.6679611650485436
# KNeighbors test score = 0.4728682170542636

# %%
model = RandomForestClassifier()
model.fit(X_train,y_train)
prediction = model.predict(X_test)
model.score(X_test,y_test)
# Out:
# 0.6511627906976745

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,prediction))
# Out:
# [[28  2  1  0]
#  [ 4 18  6  0]
#  [ 3 11 14  5]
#  [ 1  4  8 24]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.78      0.90      0.84        31
#            2       0.51      0.64      0.57        28
#            3       0.48      0.42      0.45        33
#            4       0.83      0.65      0.73        37
#
#     accuracy                           0.65       129
#    macro avg       0.65      0.65      0.65       129
# weighted avg       0.66      0.65      0.65       129

# %%
import pickle

# %%
pickle_out = open("cirrhosis.pkl","wb")
pickle.dump(model,pickle_out)
loaded_model = pickle.load(open("cirrhosis.pkl","rb"))
result = loaded_model.score(X_test,y_test)
print(result)
# Out:
# 0.6511627906976745

# %%
X_sample.head()
# Out:
#    N_Days   Age  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0   400.0  58.0       14.5        261.0     2.60   156.0    1718.0  137.95
# 1  4500.0  56.0        1.1        302.0     4.14    54.0    7394.8  113.52
# 2  1012.0  70.0        1.4        176.0     3.48   210.0     516.0   96.10
# 3  1925.0  54.0        1.8        244.0     2.54    64.0    6121.8   60.63
# 4  1504.0  38.0        3.4        279.0     3.53   143.0     671.0  113.15
#
#    Tryglicerides  Platelets  Prothrombin
# 0          172.0      190.0         12.2
# 1           88.0      221.0         10.6
# 2           55.0      151.0         12.0
# 3           92.0      183.0         10.3
# 4           72.0      136.0         10.9

# %%
X_sample[100:105]
# Out:
#      N_Days   Age  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 100  3581.0  44.0        0.9        400.0     3.60    31.0    1689.0  164.30
# 101  3099.0  56.0        0.9        248.0     3.97   172.0     646.0   62.00
# 102   110.0  48.0        2.5        188.0     3.67    57.0    1273.0  119.35
# 103  3086.0  43.0        1.1        303.0     3.64    20.0    2108.0  128.65
# 104  3092.0  34.0        1.1        464.0     4.20    38.0    1644.0  151.90
#
#      Tryglicerides  Platelets  Prothrombin
# 100          166.0      327.0         10.4
# 101           84.0      128.0         10.1
# 102          102.0      110.0         11.1
# 103           53.0      349.0         11.1
# 104          102.0      348.0         10.3

# %%
y_sample[100:105]
# Out:
# 100    3
# 101    1
# 102    4
# 103    2
# 104    3
# Name: Stage, dtype: int32

# %% [markdown]
# N_Days: number of days between registration and the earlier of death, transplantation, or study analysis time in July 1986
# Age: age in [days]
# Bilirubin: serum bilirubin in [mg/dl]
# Cholesterol: serum cholesterol in [mg/dl]
# Albumin: albumin in [gm/dl]
# Copper: urine copper in [ug/day]
# SGOT: SGOT in [U/ml]
# Triglycerides: triglicerides in [mg/dl]
# Platelets: platelets per cubic [ml/1000]
# Prothrombin: prothrombin time in seconds [s]
